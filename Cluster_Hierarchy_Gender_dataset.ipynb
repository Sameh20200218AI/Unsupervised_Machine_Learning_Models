# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram,linkage
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Training set.csv')

# %%
print(data.head(10))
# Out:
#    Height  Weight     Sex
# 0  165.65   35.41  Female
# 1  148.53   74.45  Female
# 2  167.04   81.22    Male
# 3  161.54   71.47    Male
# 4  174.31   78.18    Male
# 5  143.05   79.27  Female
# 6  149.16   63.71  Female
# 7  155.80   86.01  Female
# 8  145.37   88.33  Female
# 9  162.56   87.36    Male

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of       Height  Weight     Sex
# 0     165.65   35.41  Female
# 1     148.53   74.45  Female
# 2     167.04   81.22    Male
# 3     161.54   71.47    Male
# 4     174.31   78.18    Male
# ...      ...     ...     ...
# 2995  150.83   49.66  Female
# 2996  157.09   64.34  Female
# 2997  162.99   45.58  Female
# 2998  154.76   48.92  Female
# 2999  185.08   82.74    Male
#
# [3000 rows x 3 columns]>

# %%
print(data.describe())
# Out:
#             Height       Weight
# count  3000.000000  3000.000000
# mean    161.350427    68.400610
# std      54.912719    17.041528
# min      25.680000     8.530000
# 25%     149.502500    57.937500
# 50%     160.870000    67.370000
# 75%     171.632500    77.952500
# max    3050.000000   485.000000

# %%
# Checking Null values for training set
data.isnull().sum()*100/data.shape[0]
# Out:
# Height    0.0
# Weight    0.0
# Sex       0.0
# dtype: float64

# %%
data.shape
# Out:
# (3000, 3)

# %%
fig = plt.figure(figsize=(7,9))
ax1 = fig.add_subplot(2,2,1)
ax1.boxplot(data['Height'])
ax1.set_title('Box Plot for Height')

ax2 = fig.add_subplot(2,2,2)
ax2.boxplot(data['Weight'])
ax2.set_title('Box Plot for Weight')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#remove outliers from data training
#Q1 is the 25% and Q3 is 75% of data, Q2 is 50% of data

Q1 = data.Height.quantile(0.25)
Q3 = data.Height.quantile(0.75)
IQR = Q3 - Q1
data = data[(data.Height >= Q1 - 1.5*IQR) & (data.Height <= Q3 + 1.5*IQR)] # drop rows that include outliers

# %%
#remove outliers from data training
#Q1 is the 25% and Q3 is 75% of data, Q2 is 50% of data

Q1 = data.Weight.quantile(0.25)
Q3 = data.Weight.quantile(0.75)
IQR = Q3 - Q1
data = data[(data.Weight >= Q1 - 1.5*IQR) & (data.Weight <= Q3 + 1.5*IQR)] # drop rows that include outliers

# %%
print(data.describe())
# Out:
#             Height       Weight
# count  2966.000000  2966.000000
# mean    160.431740    68.106500
# std      14.862583    14.704601
# min     117.230000    28.410000
# 25%     149.472500    57.950000
# 50%     160.840000    67.270000
# 75%     171.597500    77.577500
# max     201.680000   107.860000

# %%
#scatter row data
plt.scatter(data['Weight'],data['Height'],label='row data',marker='*')
plt.title('Data')
plt.xlabel('Weight')
plt.ylabel('Height')
plt.legend()
plt.show()

# %%
x=np.array(data[['Weight','Height']].values)

# %%
print(x.shape)
# Out:
# (2966, 2)

# %%
model = AgglomerativeClustering(affinity='euclidean',linkage='ward')

# %%
hc = dendrogram(linkage(x[:150,:],method='ward'))
plt.title('Hierarchy Graph')
plt.xlabel('x values')
plt.ylabel('Distance')
plt.tight_layout()
plt.show()

# %%
pred_labels = model.fit_predict(x)
# Out:
# c:\Users\Sameh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
print(pred_labels)
# Out:
# [0 1 0 ... 1 1 0]

# %%
lables = set(model.labels_)

print('Labels : ',lables)
# Out:
# Labels :  {0, 1}

# %%
plt.scatter(x[pred_labels==0,0],x[pred_labels==0,1], color='red',alpha=0.4,label='Cluster 0',marker='*')
    
plt.scatter(x[pred_labels==1,0],x[pred_labels==1,1], color='blue',alpha=0.6,label='Cluster 1',marker='*')
plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Weight VS Height')
plt.legend()
plt.tight_layout()
plt.show()

# %%
model_2 = AgglomerativeClustering(n_clusters=7,affinity='euclidean',linkage='ward')

# %%
pred_labels_2 = model_2.fit_predict(x)
# Out:
# c:\Users\Sameh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
print(pred_labels_2)
# Out:
# [5 0 1 ... 3 3 6]

# %%
labels_2 = set(model_2.labels_)

print('Labels : ',labels_2)
# Out:
# Labels :  {0, 1, 2, 3, 4, 5, 6}

# %%
plt.scatter(x[pred_labels_2==0,0],x[pred_labels_2==0,1], color='red',alpha=0.4,label='Cluster 0',marker='*')
    
plt.scatter(x[pred_labels_2==1,0],x[pred_labels_2==1,1], color='blue',alpha=0.6,label='Cluster 1',marker='*')

plt.scatter(x[pred_labels_2==2,0],x[pred_labels_2==2,1], color='green',alpha=0.6,label='Cluster 2',marker='*')
    
plt.scatter(x[pred_labels_2==3,0],x[pred_labels_2==3,1], color='cyan',alpha=0.9,label='Cluster 3',marker='*')

plt.scatter(x[pred_labels_2==4,0],x[pred_labels_2==4,1], color='orange',alpha=0.6,label='Cluster 4',marker='*')
    
plt.scatter(x[pred_labels_2==5,0],x[pred_labels_2==5,1], color='yellow',alpha=0.6,label='Cluster 5',marker='*')

plt.scatter(x[pred_labels_2==6,0],x[pred_labels_2==6,1], color='brown',alpha=0.6,label='Cluster 6',marker='*')
    

plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Weight VS Height')
plt.legend()
plt.tight_layout()
plt.show()
